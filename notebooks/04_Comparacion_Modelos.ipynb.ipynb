# %% [markdown]
# ## **Comparación entre Modelo Binario vs Modelo Regresion**

# %%
# Clases
from models.clasificacion_binaria import ClasificacionBinaria, prueba_binaria
from models.Modelo_Regresion import ModeloRegresion, modelo

# %%
# Llamamos de cada clase sus metricas para la comparacion
modelo.prediccion_acc(modelo.X_test, y_test) # De la clase regresion
prueba_binaria.evaluar_modelo(X_test, y_test, modelo_creado)
